# %% [markdown]
# # Climate-Alpha: Quantitative ESG Trading Platform
# ## Complete Demonstration Notebook
#
# This notebook demonstrates all components of the Climate-Alpha platform:
# 1. Data Collection
# 2. Feature Engineering
# 3. LSTM Price Prediction
# 4. Pairs Trading Strategy
# 5. Portfolio Optimization
# 6. Risk Management

# %%
# Import libraries
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import backend.data.features as features
import importlib
importlib.reload(features) 

from backend.data.collectors import DataCollector
from backend.data.features import FeatureEngineer
from backend.models.lstm_predictor import LSTMPredictor
from backend.strategies.pairs_trading import PairsTradingStrategy
from backend.risk.portfolio_opt import PortfolioOptimizer
from backend.risk.var_calculator import RiskCalculator
from backend.utils.metrics import PerformanceMetrics

# Plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

print("All modules imported successfully")
# Out:
# All modules imported successfully

# %% [markdown]
# ## 1. Data Collection

# %%
# Initialize data collector
collector = DataCollector()

# Download full universe
print("Downloading market data...")
data = collector.download_full_universe(
    start_date="2019-01-01",
    end_date="2025-12-31"
)

print(f"\nData shape: {data.shape}")
print(f"Date range: {data.index[0]} to {data.index[-1]}")
print(f"\nTickers: {data.columns.get_level_values(0).unique().tolist()}")
# Out:
# Downloading market data...
# 2026-03-07 14:11:04 - climate_alpha - INFO - download_full_universe:249 - Downloading full universe: 32 tickers
# 2026-03-07 14:11:04 - climate_alpha - INFO - download_stock_data:54 - Downloading data for 32 tickers from 2019-01-01 to 2024-12-31
# 2026-03-07 14:11:04 - climate_alpha - INFO - download_stock_data:60 - Downloading ICLN...
# 2026-03-07 14:11:06 - climate_alpha - INFO - download_stock_data:71 - ICLN: 1509 rows
# 2026-03-07 14:11:06 - climate_alpha - INFO - download_stock_data:60 - Downloading TAN...
# 2026-03-07 14:11:06 - climate_alpha - INFO - download_stock_data:71 - TAN: 1509 rows
# 2026-03-07 14:11:06 - climate_alpha - INFO - download_stock_data:60 - Downloading QCLN...
# 2026-03-07 14:11:07 - climate_alpha - INFO - download_stock_data:71 - QCLN: 1509 rows
# 2026-03-07 14:11:07 - climate_alpha - INFO - download_stock_data:60 - Downloading PBW...
# 2026-03-07 14:11:07 - climate_alpha - INFO - download_stock_data:71 - PBW: 1509 rows
# 2026-03-07 14:11:07 - climate_alpha - INFO - download_stock_data:60 - Downloading FAN...
# 2026-03-07 14:11:08 - climate_alpha - INFO - download_stock_data:71 - FAN: 1509 rows
# 2026-03-07 14:11:08 - climate_alpha - INFO - download_stock_data:60 - Downloading ACES...
# 2026-03-07 14:11:08 - climate_alpha - INFO - download_stock_data:71 - ACES: 1509 rows
# 2026-03-07 14:11:08 - climate_alpha - INFO - download_stock_data:60 - Downloading ENPH...
# 2026-03-07 14:11:09 - climate_alpha - INFO - download_stock_data:71 - ENPH: 1509 rows
# 2026-03-07 14:11:09 - climate_alpha - INFO - download_stock_data:60 - Downloading SEDG...
# 2026-03-07 14:11:10 - climate_alpha - INFO - download_stock_data:71 - SEDG: 1509 rows
# 2026-03-07 14:11:10 - climate_alpha - INFO - download_stock_data:60 - Downloading FSLR...
# 2026-03-07 14:11:10 - climate_alpha - INFO - download_stock_data:71 - FSLR: 1509 rows
# 2026-03-07 14:11:10 - climate_alpha - INFO - download_stock_data:60 - Downloading RUN...
# 2026-03-07 14:11:10 - climate_alpha - INFO - download_stock_data:71 - RUN: 1509 rows
# 2026-03-07 14:11:11 - climate_alpha - INFO - download_stock_data:60 - Downloading NEE...
# 2026-03-07 14:11:11 - climate_alpha - INFO - download_stock_data:71 - NEE: 1509 rows
# 2026-03-07 14:11:11 - climate_alpha - INFO - download_stock_data:60 - Downloading BEP...
# 2026-03-07 14:11:12 - climate_alpha - INFO - download_stock_data:71 - BEP: 1509 rows
# 2026-03-07 14:11:12 - climate_alpha - INFO - download_stock_data:60 - Downloading PLUG...
# 2026-03-07 14:11:12 - climate_alpha - INFO - download_stock_data:71 - PLUG: 1509 rows
# 2026-03-07 14:11:12 - climate_alpha - INFO - download_stock_data:60 - Downloading BE...
# 2026-03-07 14:11:13 - climate_alpha - INFO - download_stock_data:71 - BE: 1509 rows
# 2026-03-07 14:11:13 - climate_alpha - INFO - download_stock_data:60 - Downloading NOVA...
# $NOVA: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NOVA']: possibly delisted; no timezone found
# 2026-03-07 14:11:14 - climate_alpha - WARNING - download_stock_data:73 - NOVA: No data returned
# 2026-03-07 14:11:14 - climate_alpha - INFO - download_stock_data:60 - Downloading ARRY...
# 2026-03-07 14:11:15 - climate_alpha - INFO - download_stock_data:71 - ARRY: 1058 rows
# 2026-03-07 14:11:15 - climate_alpha - INFO - download_stock_data:60 - Downloading XLE...
# 2026-03-07 14:11:15 - climate_alpha - INFO - download_stock_data:71 - XLE: 1509 rows
# 2026-03-07 14:11:15 - climate_alpha - INFO - download_stock_data:60 - Downloading XOP...
# 2026-03-07 14:11:16 - climate_alpha - INFO - download_stock_data:71 - XOP: 1509 rows
# 2026-03-07 14:11:16 - climate_alpha - INFO - download_stock_data:60 - Downloading IEO...
# 2026-03-07 14:11:17 - climate_alpha - INFO - download_stock_data:71 - IEO: 1509 rows
# 2026-03-07 14:11:17 - climate_alpha - INFO - download_stock_data:60 - Downloading XOM...
# 2026-03-07 14:11:17 - climate_alpha - INFO - download_stock_data:71 - XOM: 1509 rows
# 2026-03-07 14:11:17 - climate_alpha - INFO - download_stock_data:60 - Downloading CVX...
# 2026-03-07 14:11:18 - climate_alpha - INFO - download_stock_data:71 - CVX: 1509 rows
# 2026-03-07 14:11:18 - climate_alpha - INFO - download_stock_data:60 - Downloading COP...
# 2026-03-07 14:11:18 - climate_alpha - INFO - download_stock_data:71 - COP: 1509 rows
# 2026-03-07 14:11:19 - climate_alpha - INFO - download_stock_data:60 - Downloading SLB...
# 2026-03-07 14:11:19 - climate_alpha - INFO - download_stock_data:71 - SLB: 1509 rows
# 2026-03-07 14:11:19 - climate_alpha - INFO - download_stock_data:60 - Downloading EOG...
# 2026-03-07 14:11:20 - climate_alpha - INFO - download_stock_data:71 - EOG: 1509 rows
# 2026-03-07 14:11:20 - climate_alpha - INFO - download_stock_data:60 - Downloading MPC...
# 2026-03-07 14:11:20 - climate_alpha - INFO - download_stock_data:71 - MPC: 1509 rows
# 2026-03-07 14:11:20 - climate_alpha - INFO - download_stock_data:60 - Downloading PSX...
# 2026-03-07 14:11:22 - climate_alpha - INFO - download_stock_data:71 - PSX: 1509 rows
# 2026-03-07 14:11:22 - climate_alpha - INFO - download_stock_data:60 - Downloading VLO...
# 2026-03-07 14:11:22 - climate_alpha - INFO - download_stock_data:71 - VLO: 1509 rows
# 2026-03-07 14:11:23 - climate_alpha - INFO - download_stock_data:60 - Downloading OXY...
# 2026-03-07 14:11:23 - climate_alpha - INFO - download_stock_data:71 - OXY: 1509 rows
# 2026-03-07 14:11:23 - climate_alpha - INFO - download_stock_data:60 - Downloading HAL...
# 2026-03-07 14:11:24 - climate_alpha - INFO - download_stock_data:71 - HAL: 1509 rows
# 2026-03-07 14:11:24 - climate_alpha - INFO - download_stock_data:60 - Downloading SPY...
# 2026-03-07 14:11:24 - climate_alpha - INFO - download_stock_data:71 - SPY: 1509 rows
# 2026-03-07 14:11:24 - climate_alpha - INFO - download_stock_data:60 - Downloading TLT...
# 2026-03-07 14:11:25 - climate_alpha - INFO - download_stock_data:71 - TLT: 1509 rows
# 2026-03-07 14:11:25 - climate_alpha - INFO - download_stock_data:60 - Downloading GLD...
# 2026-03-07 14:11:25 - climate_alpha - INFO - download_stock_data:71 - GLD: 1509 rows
# 2026-03-07 14:11:26 - climate_alpha - INFO - download_stock_data:90 - Saved data to data\raw\market_data_2019-01-01_2024-12-31.csv
#
# Data shape: (1509, 155)
# Date range: 2019-01-02 00:00:00 to 2024-12-30 00:00:00
#
# Tickers: ['ICLN', 'TAN', 'QCLN', 'PBW', 'FAN', 'ACES', 'ENPH', 'SEDG', 'FSLR', 'RUN', 'NEE', 'BEP', 'PLUG', 'BE', 'ARRY', 'XLE', 'XOP', 'IEO', 'XOM', 'CVX', 'COP', 'SLB', 'EOG', 'MPC', 'PSX', 'VLO', 'OXY', 'HAL', 'SPY', 'TLT', 'GLD']

# %%
# Extract closing prices
close_prices = data.xs('Close', axis=1, level=1)

# Plot price evolution
fig, axes = plt.subplots(2, 1, figsize=(15, 10))

# Clean energy
clean_tickers = ['ICLN', 'TAN', 'ENPH', 'FSLR']
for ticker in clean_tickers:
    if ticker in close_prices.columns:
        axes[0].plot(close_prices.index, close_prices[ticker], label=ticker)
axes[0].set_title('Clean Energy Securities', fontsize=14, fontweight='bold')
axes[0].set_ylabel('Price ($)')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Traditional energy
traditional_tickers = ['XLE', 'XOM', 'CVX']
for ticker in traditional_tickers:
    if ticker in close_prices.columns:
        axes[1].plot(close_prices.index, close_prices[ticker], label=ticker)
axes[1].set_title('Traditional Energy Securities', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Price ($)')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Feature Engineering

# %%
# Select a ticker for feature engineering demo
ticker = 'ICLN'
ticker_data = data[ticker].copy()

# Initialize feature engineer
engineer = FeatureEngineer()

# Create complete feature set
features = engineer.create_feature_set(
    ticker_data,
    technical=True,
    price=True,
    volume=True,
    volatility=True,
    momentum=True,
    time=True
)

print(f"Original columns: {len(ticker_data.columns)}")
print(f"Feature columns: {len(features.columns)}")
print(f"\nFeature list (first 20):")
print(features.columns.tolist()[:20])
# Out:
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_technical_features:29 - Adding technical features...
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_technical_features:101 - Added 21 technical features
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_price_features:115 - Adding price features...
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_price_features:161 - Added price features
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_volume_features:175 - Adding volume features...
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_volume_features:200 - Added volume features
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_volatility_features:214 - Adding volatility features...
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_volatility_features:251 - Added volatility features
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_momentum_features:265 - Adding momentum features...
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_momentum_features:293 - Added momentum features
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_time_features:307 - Adding time features...
# 2026-03-07 14:11:27 - climate_alpha - INFO - add_time_features:329 - Added time features
# 2026-03-07 14:11:27 - climate_alpha - INFO - create_feature_set:380 - Feature engineering complete: 88 columns, dropped 199 rows with NaN
# Original columns: 5
# Feature columns: 88
#
# Feature list (first 20):
# [('Close', 'ICLN'), ('High', 'ICLN'), ('Low', 'ICLN'), ('Open', 'ICLN'), ('Volume', 'ICLN'), ('sma_20', ''), ('sma_50', ''), ('sma_200', ''), ('ema_12', ''), ('ema_26', ''), ('macd', ''), ('macd_signal', ''), ('macd_diff', ''), ('rsi_14', ''), ('bb_high', ''), ('bb_mid', ''), ('bb_low', ''), ('bb_width', ''), ('atr_14', ''), ('adx_14', '')]

# %% [markdown]
# ## 3. LSTM Price Prediction

# %%
# Prepare data for LSTM
predictor = LSTMPredictor(lookback_days=60, lstm_units=[128, 64, 32])

# Use Close price and a few key features
feature_cols = ['Close', 'sma_20', 'rsi_14', 'macd', 'obv']
X, y = predictor.prepare_data(features, target_col='Close', feature_cols=feature_cols)

# Split train/test (80/20)
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

print(f"Train set: {X_train.shape}")
print(f"Test set: {X_test.shape}")
# Out:
# 2026-03-07 14:11:27 - climate_alpha - INFO - prepare_data:85 - Prepared data: X shape (1250, 60, 5), y shape (1250, 1)
# Train set: (1000, 60, 5)
# Test set: (250, 60, 5)

# %%
# Train LSTM model
history = predictor.train(
    X_train, y_train,
    X_test, y_test,
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 2026-03-07 14:11:27 - climate_alpha - INFO - build_model:124 - Built LSTM model with 130465 parameters
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0453 - mae: 0.1576
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - loss: 0.0218 - mae: 0.1067 - val_loss: 0.0015 - val_mae: 0.0344 - learning_rate: 0.0010
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0060 - mae: 0.0594
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - loss: 0.0059 - mae: 0.0584 - val_loss: 6.5643e-04 - val_mae: 0.0209 - learning_rate: 0.0010
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - loss: 0.0054 - mae: 0.0556 - val_loss: 9.1993e-04 - val_mae: 0.0254 - learning_rate: 0.0010
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - loss: 0.0049 - mae: 0.0532 - val_loss: 8.5490e-04 - val_mae: 0.0241 - learning_rate: 0.0010
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0044 - mae: 0.0519
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - loss: 0.0046 - mae: 0.0521 - val_loss: 3.3519e-04 - val_mae: 0.0149 - learning_rate: 0.0010
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - loss: 0.0044 - mae: 0.0496 - val_loss: 3.8342e-04 - val_mae: 0.0157 - learning_rate: 0.0010
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 0.0042 - mae: 0.0497 - val_loss: 0.0017 - val_mae: 0.0364 - learning_rate: 0.0010
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 0.0044 - mae: 0.0503 - val_loss: 4.7367e-04 - val_mae: 0.0178 - learning_rate: 0.0010
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0037 - mae: 0.0474 - val_loss: 4.0555e-04 - val_mae: 0.0166 - learning_rate: 0.0010
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0039 - mae: 0.0476 - val_loss: 0.0012 - val_mae: 0.0304 - learning_rate: 0.0010
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0037 - mae: 0.0471
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 0.0037 - mae: 0.0464 - val_loss: 3.0476e-04 - val_mae: 0.0142 - learning_rate: 5.0000e-04
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 0.0036 - mae: 0.0460 - val_loss: 4.0209e-04 - val_mae: 0.0164 - learning_rate: 5.0000e-04
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - loss: 0.0035 - mae: 0.0451 - val_loss: 4.7591e-04 - val_mae: 0.0178 - learning_rate: 5.0000e-04
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0033 - mae: 0.0451
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.0034 - mae: 0.0457 - val_loss: 2.9158e-04 - val_mae: 0.0139 - learning_rate: 5.0000e-04
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0035 - mae: 0.0453 - val_loss: 3.8303e-04 - val_mae: 0.0162 - learning_rate: 5.0000e-04
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0038 - mae: 0.0461

# %%
# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].plot(history.history['loss'], label='Train Loss')
axes[0].plot(history.history['val_loss'], label='Val Loss')
axes[0].set_title('Model Loss', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['mae'], label='Train MAE')
axes[1].plot(history.history['val_mae'], label='Val MAE')
axes[1].set_title('Model MAE', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('MAE')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Evaluate model
metrics = predictor.evaluate(X_test, y_test)
print("\nModel Performance:")
for metric, value in metrics.items():
    print(f"  {metric}: {value:.4f}")

# %% [markdown]
# ## 4. Pairs Trading Strategy

# %%
# Initialize pairs trading strategy
pairs_strategy = PairsTradingStrategy(
    lookback_period=252,
    entry_zscore=2.0,
    exit_zscore=0.5
)

# Find cointegrated pairs
pairs = pairs_strategy.find_cointegrated_pairs(close_prices)

print(f"\nFound {len(pairs)} cointegrated pairs:")
for ticker1, ticker2, p_value in pairs[:5]:
    print(f"  {ticker1} - {ticker2}: p-value = {p_value:.4f}")

# %%
# Backtest best pair
if pairs:
    ticker1, ticker2, _ = pairs[0]
    s1 = close_prices[ticker1]
    s2 = close_prices[ticker2]
    
    results = pairs_strategy.backtest_pair(s1, s2, initial_capital=100000)
    
    print(f"\n{'='*60}")
    print(f"PAIRS TRADING BACKTEST: {ticker1} - {ticker2}")
    print(f"{'='*60}")
    print(f"Total Return:        {results['total_return']:>10.2%}")
    print(f"Annual Return:       {results['annual_return']:>10.2%}")
    print(f"Annual Volatility:   {results['annual_volatility']:>10.2%}")
    print(f"Sharpe Ratio:        {results['sharpe_ratio']:>10.2f}")
    print(f"Max Drawdown:        {results['max_drawdown']:>10.2%}")
    print(f"Win Rate:            {results['win_rate']:>10.2%}")
    print(f"Number of Trades:    {results['num_trades']:>10.0f}")
    print(f"{'='*60}")

# %% [markdown]
# ## 5. Portfolio Optimization

# %%
# Select clean energy universe for portfolio
portfolio_tickers = ['ICLN', 'TAN', 'ENPH', 'FSLR', 'NEE']
portfolio_prices = close_prices[portfolio_tickers].dropna()
portfolio_returns = portfolio_prices.pct_change().dropna()

# Initialize optimizer
optimizer = PortfolioOptimizer(risk_free_rate=0.02)

# Mean-Variance Optimization
mv_result = optimizer.mean_variance_optimization(portfolio_returns)

print("\nMean-Variance Optimal Portfolio:")
print(mv_result['weights'])
print(f"\nExpected Return: {mv_result['expected_return']:.2%}")
print(f"Volatility: {mv_result['volatility']:.2%}")
print(f"Sharpe Ratio: {mv_result['sharpe_ratio']:.2f}")

# %%
# Risk Parity Optimization
rp_result = optimizer.risk_parity_optimization(portfolio_returns)

print("\nRisk Parity Portfolio:")
print(rp_result['weights'])
print(f"\nExpected Return: {rp_result['expected_return']:.2%}")
print(f"Volatility: {rp_result['volatility']:.2%}")
print(f"Sharpe Ratio: {rp_result['sharpe_ratio']:.2f}")

# %%
# ESG-Constrained Optimization
esg_scores = pd.Series({
    'ICLN': 8.5,
    'TAN': 8.0,
    'ENPH': 7.5,
    'FSLR': 8.2,
    'NEE': 9.0
})

esg_result = optimizer.esg_constrained_optimization(
    portfolio_returns,
    esg_scores,
    min_esg_score=7.5
)

print("\nESG-Constrained Portfolio:")
print(esg_result['weights'])
print(f"\nExpected Return: {esg_result['expected_return']:.2%}")
print(f"Volatility: {esg_result['volatility']:.2%}")
print(f"Sharpe Ratio: {esg_result['sharpe_ratio']:.2f}")
print(f"ESG Score: {esg_result['esg_score']:.1f}")

# %% [markdown]
# ## 6. Risk Management

# %%
# Initialize risk calculator
risk_calc = RiskCalculator()

# Use ICLN returns for risk analysis
icln_returns = portfolio_returns['ICLN']

# Generate comprehensive risk report
risk_report = risk_calc.comprehensive_risk_report(
    icln_returns,
    portfolio_value=1000000
)

risk_calc.print_risk_report(risk_report)

# %%
# Stress Testing
scenarios = {
    '2008 Financial Crisis': -0.35,
    'COVID-19 Pandemic': -0.25,
    'Climate Scenario 2°C': -0.10,
    'Climate Scenario 3°C': -0.20,
    'Climate Scenario 4°C': -0.30,
    'Carbon Tax Implementation': -0.15
}

stress_results = risk_calc.stress_test(
    icln_returns,
    portfolio_value=1000000,
    scenarios=scenarios
)

print("\nStress Test Results:")
print(stress_results.to_string(index=False))

# %% [markdown]
# ## 7. Performance Summary

# %%
# Calculate performance metrics for the portfolio
benchmark_returns = close_prices['SPY'].pct_change().dropna()

metrics_calc = PerformanceMetrics(
    returns=icln_returns,
    benchmark_returns=benchmark_returns,
    risk_free_rate=0.02
)

metrics_calc.print_summary()

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrated:
# - ✅ Data collection and processing
# - ✅ Feature engineering with 100+ technical indicators
# - ✅ LSTM deep learning for price prediction
# - ✅ Pairs trading with cointegration analysis
# - ✅ Portfolio optimization (Mean-Variance, Risk Parity, ESG-constrained)
# - ✅ Comprehensive risk management (VaR, CVaR, stress testing)
#
# This platform addresses **UN SDG 13 (Climate Action)** and **SDG 7 (Affordable Clean Energy)** while demonstrating advanced quantitative finance skills.
